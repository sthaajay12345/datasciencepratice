# %%
import pandas as pd

# %%
a=pd.DataFrame({'a':[1,2,3],"b":[10,20,30]})
b=pd.DataFrame({'c':[4,5,6],"d":[50,70,90]})
display(a,b)
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30
#    c   d
# 0  4  50
# 1  5  70
# 2  6  90

# %%
a.join(b)
# Out:
#    a   b  c   d
# 0  1  10  4  50
# 1  2  20  5  70
# 2  3  30  6  90

# %%
c=pd.DataFrame({'a':[1,2,3],"c":[10,20,30]})

# %%
c.join(b,rsuffix='_ac')
# Out:
#    a   c  c_ac   d
# 0  1  10     4  50
# 1  2  20     5  70
# 2  3  30     6  90

# %%
display(a,b)
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30
#    c   d
# 0  4  50
# 1  5  70
# 2  6  90

# %%
d=pd.DataFrame({'d':[1,2,3],"e":[10,20,30]},index=['a','b','c'])
d
# Out:
#    d   e
# a  1  10
# b  2  20
# c  3  30

# %%
display(a,b,c,d)
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30
#    c   d
# 0  4  50
# 1  5  70
# 2  6  90
#    a   c
# 0  1  10
# 1  2  20
# 2  3  30
#    d   e
# a  1  10
# b  2  20
# c  3  30

# %%
b.join(c,how='left',rsuffix='ab')
# Out:
#    c   d  a  cab
# 0  4  50  1   10
# 1  5  70  2   20
# 2  6  90  3   30

# %%
abc=pd.DataFrame({'a':[1,2,3,4,5],"b":[10,20,30,40,50]})

# %%
b
# Out:
#    c   d
# 0  4  50
# 1  5  70
# 2  6  90

# %%
b.join(abc)
# Out:
#    c   d  a   b
# 0  4  50  1  10
# 1  5  70  2  20
# 2  6  90  3  30

# %%
b.join(abc,how='outer')
# Out:
#      c     d  a   b
# 0  4.0  50.0  1  10
# 1  5.0  70.0  2  20
# 2  6.0  90.0  3  30
# 3  NaN   NaN  4  40
# 4  NaN   NaN  5  50

# %%
b.join(abc,how='right')
# Out:
#      c     d  a   b
# 0  4.0  50.0  1  10
# 1  5.0  70.0  2  20
# 2  6.0  90.0  3  30
# 3  NaN   NaN  4  40
# 4  NaN   NaN  5  50

# %%
b.join(abc)
# Out:
#    c   d  a   b
# 0  4  50  1  10
# 1  5  70  2  20
# 2  6  90  3  30

# %% [markdown]
# **Append function**

# %%
a=pd.DataFrame({'a':[1,2,3,4],'b':[10,20,30,40]})
b=pd.DataFrame({'a':[11,12,13,14],'b':[11,22,33,44]})
c=pd.DataFrame({'a':[21,22,33,44],'b':[9,8,7,6]})
display(a,b,c)
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
#     a   b
# 0  11  11
# 1  12  22
# 2  13  33
# 3  14  44
#     a  b
# 0  21  9
# 1  22  8
# 2  33  7
# 3  44  6

# %%
a.append(b,c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-3f810d7ed7bf> in <module>
# ----> 1 a.append(b,c)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7741         else:
#    7742             to_concat = [self, other]
# -> 7743         return concat(
#    7744             to_concat,
#    7745             ignore_index=ignore_index,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ...

# %%
a.append(b,c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-3f810d7ed7bf> in <module>
# ----> 1 a.append(b,c)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7741         else:
#    7742             to_concat = [self, other]
# -> 7743         return concat(
#    7744             to_concat,
#    7745             ignore_index=ignore_index,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ...

# %%
a.append([b,c])
# Out:
#     a   b
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40
# 0  11  11
# 1  12  22
# 2  13  33
# 3  14  44
# 0  21   9
# 1  22   8
# 2  33   7
# 3  44   6

# %%
a.append([b,c],)
