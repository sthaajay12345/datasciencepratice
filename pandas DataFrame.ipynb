# %% [markdown]
# **how to create python pandas dataframe**

# %%
import pandas as pd

# %%
empt_df=pd.DataFrame()

# %%
print(empt_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
a=['a','b','c','d']
print(a)
# Out:
# ['a', 'b', 'c', 'd']

# %%
df=pd.DataFrame(a)

# %%
print(df)
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d

# %%
df
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d

# %%
ls_ls=[[1,2,3],[2,3,4],[4,5,6]]
ls_ls
# Out:
# [[1, 2, 3], [2, 3, 4], [4, 5, 6]]

# %%
df1=pd.DataFrame(ls_ls)
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  2  3  4
# 2  4  5  6

# %%
dict1={'id':[11,22,33,44]}
dict1
# Out:
# {'id': [11, 22, 33, 44]}

# %%
df3=pd.DataFrame(dict1)
df3
# Out:
#    id
# 0  11
# 1  22
# 2  33
# 3  44

# %%
dict1={'name':['ajay','sanjay','alish','bishnu'],'sn':[1,2,3,4]}
dict1
# Out:
# {'name': ['ajay', 'sanjay', 'alish', 'bishnu'], 'sn': [1, 2, 3, 4]}

# %%
df=pd.DataFrame(dict1)
df
# Out:
#      name  sn
# 0    ajay   1
# 1  sanjay   2
# 2   alish   3
# 3  bishnu   4

# %%
ls_dict=[{'a':1,'b':2},{'a':3,'b':4}]
df=pd.DataFrame(ls_dict)
df
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
ls_dict=[{'a':1,'b':2},{'a':3,'b':4,'c':5}]
df=pd.DataFrame(ls_dict)
df
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0

# %%
dict_sr={'Id':pd.Series([1,2,3]),'sn':pd.Series([111,222,333])}
df=pd.DataFrame(dict_sr)
df
# Out:
#    Id   sn
# 0   1  111
# 1   2  222
# 2   3  333

# %%
data=pd.read_csv('E:\my\pokemon_data.csv')
data
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
data=pd.read_csv('E:\my\pokemon_data.csv', nrows=1)
data
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
data=pd.read_csv('E:\my\pokemon_data.csv',nrows=5)
data
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
data=pd.read_csv('E:\my\pokemon_data.csv',usecols=[1])
data
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
data=pd.read_csv('E:\my\pokemon_data.csv',usecols=[0,1])
data
# Out:
#        #                   Name
# 0      1              Bulbasaur
# 1      2                Ivysaur
# 2      3               Venusaur
# 3      3  VenusaurMega Venusaur
# 4      4             Charmander
# ..   ...                    ...
# 795  719                Diancie
# 796  719    DiancieMega Diancie
# 797  720    HoopaHoopa Confined
# 798  720     HoopaHoopa Unbound
# 799  721              Volcanion
#
# [800 rows x 2 columns]

# %%
da=pd.read_csv('E:\my\pokemon_data.csv',skiprows=[1])
da
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      2                Ivysaur    Grass  Poison  60      62       63
# 1      3               Venusaur    Grass  Poison  80      82       83
# 2      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 3      4             Charmander     Fire     NaN  39      52       43
# 4      5             Charmeleon     Fire     NaN  58      64       58
# ..   ...                    ...      ...     ...  ..     ...      ...
# 794  719                Diancie     Rock   Fairy  50     100      150
# 795  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 796  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 797  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 798  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         80       80     60           1      False
# ...

# %%
da=pd.read_csv('E:\my\pokemon_data.csv',index_col='HP')
da
# Out:
#       #                   Name   Type 1  Type 2  Attack  Defense  Sp. Atk  \
# HP
# 45    1              Bulbasaur    Grass  Poison      49       49       65
# 60    2                Ivysaur    Grass  Poison      62       63       80
# 80    3               Venusaur    Grass  Poison      82       83      100
# 80    3  VenusaurMega Venusaur    Grass  Poison     100      123      122
# 39    4             Charmander     Fire     NaN      52       43       60
# ..  ...                    ...      ...     ...     ...      ...      ...
# 50  719                Diancie     Rock   Fairy     100      150      100
# 50  719    DiancieMega Diancie     Rock   Fairy     160      110      160
# 80  720    HoopaHoopa Confined  Psychic   Ghost     110       60      150
# 80  720     HoopaHoopa Unbound  Psychic    Dark     160       60      170
# 80  721              Volcanion     Fire   Water     110      120      130
#
#     Sp. Def  Speed  Generation  Legendary
# HP
# ...
