# %% [markdown]
# **pandas Replace()**

# %%
import pandas as pd

# %%
data=pd.read_csv('E:\my\pokemon_data.csv')
data
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
h=data.head(5)
h
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
h.replace(to_replace='Grass',value='demo')
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur   demo  Poison  45      49       49       65
# 1  2                Ivysaur   demo  Poison  60      62       63       80
# 2  3               Venusaur   demo  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur   demo  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
h.replace([1,2,3,4],0)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  0              Bulbasaur  Grass  Poison  45      49       49       65
# 1  0                Ivysaur  Grass  Poison  60      62       63       80
# 2  0               Venusaur  Grass  Poison  80      82       83      100
# 3  0  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  0             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           0      False
# 1       80     60           0      False
# 2      100     80           0      False
# 3      120     80           0      False
# 4       50     65           0      False

# %%
h.replace(to_replace=0,value=[1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8a9e9e538af1> in <module>
# ----> 1 h.replace(to_replace=0,value=[1,2,3,4,5])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4377         method="pad",
#    4378     ):
# -> 4379         return super().replace(
#    4380             to_replace=to_replace,
#    4381             value=value,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6584                     )
#    6585                 else:
# -> 6586                     raise TypeError(
#    6587                         f'Invalid "to_replace" type: {repr(type(to_replace).__name__)}'
#    6588                     )
#
# TypeError: Invalid "to_replace" type: 'int'

# %%
h
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
h.replace([1,2,3,3,4],[10,11,12,13,14])
# Out:
#     #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  10              Bulbasaur  Grass  Poison  45      49       49       65
# 1  11                Ivysaur  Grass  Poison  60      62       63       80
# 2  13               Venusaur  Grass  Poison  80      82       83      100
# 3  13  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  14             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45          10      False
# 1       80     60          10      False
# 2      100     80          10      False
# 3      120     80          10      False
# 4       50     65          10      False

# %%
h.drop_duplicates(subset='#', keep='first')
# Out:
#    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2     Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3    Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  4  Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 4           1      False

# %%
h.rename(columns={'Name':'Names'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-fd7e20b3d5ac> in <module>
# ----> 1 h.rename(columns={'Name':'Names'})
#
# TypeError: 'dict' object is not callable

# %%
h.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
h['#']=h['#'].astype(int)
# Out:
# <ipython-input-26-5ef4af77ea06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h['#']=h['#'].astype(int)

# %%
h.rename(columns={'Name':'ajay'},axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-c77953896189> in <module>
# ----> 1 h.rename(columns={'Name':'ajay'},axis=1)
#
# TypeError: 'dict' object is not callable
